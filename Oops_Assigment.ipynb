# %% [markdown]
# # 1.What is Object-Oriented Programming (OOP)?
# Answer:-Object-Oriented Programming (OOP) is a way of writing code where you organize everything into objects (just like real-world things).
# Each object has properties (data) and behaviors (actions).

# %% [markdown]
# # 2.What is a class in OOP?
# Answer:-A class is a blueprint or template for creating objects.
# It defines what data (attributes) and what actions (methods) the objects will have.

# %% [markdown]
# # 3.What is an object in OOP?
# Answer:-An object is a real-world entity created from a class blueprint.
# It is an instance of a class  meaning it’s a copy of the blueprint with actual values filled in.

# %% [markdown]
# # 4.What is the difference between abstraction and encapsulation?
# Answer:-Abstraction means showing only the essential features and hiding the internal details of a program.
# It focuses on what to do, not on how to do it.
# In Python, abstraction can be achieved using abstract classes and methods (using the abc module).
# Example: A user can start a car by pressing a button without knowing how the engine works.
#
# Encapsulation:-In Python, encapsulation is achieved using private variables and getter/setter methods.
# Example: A car’s engine is protected inside the bonnet — users can’t access it directly.

# %% [markdown]
# 5.What are dunder methods in Python?
# Answer:-Dunder methods  are those built-in methods in Python whose names start and end with double underscores (__).

# %% [markdown]
# # 6. Explain the concept of inheritance in OOP.
# Answer:-Inheritance is a concept in OOP where one class (child/subclass) can acquire the properties and methods of another class (parent/superclass).
# It allows code reusability and helps to create a relationship between classes.

# %% [markdown]
# # 7.What is polymorphism in OOP
# Answer:-The word Polymorphism comes from two Greek words —
# “Poly” means many and “morph” means forms.
# So, Polymorphism means “many forms.”
#
# In OOP, polymorphism allows the same function or method to behave differently depending on the object that calls it.

# %% [markdown]
# # 8.How is encapsulation achieved in Python?
# Answer:-Encapsulation means binding data (variables) and methods (functions) together into a single unit (class)
# and restricting direct access to some of the object’s data - to protect it from being accidentally modified.

# %% [markdown]
# # 9.What is a constructor in Python
# Answer:-A constructor in Python is a special method that is automatically called when an object of a class is created. It is used to initialize the object’s attributes

# %% [markdown]
# # 10.What are class and static methods in Python
# Answer:-A class method is a method that belongs to the class, not the object (instance). It can access and modify class-level data (variables shared by all objects).

# %% [markdown]
# # 11.What is method overloading in Python
# Answer:-Method Overloading means defining multiple methods with the same name but different parameters (like different number or type of arguments). In languages like Java or C++, this is directly supported.
# But Python does NOT support traditional method overloading.

# %% [markdown]
# # 12.What is method overriding in OOP
# Answer:-When a child class (subclass) defines a method with the same name as one in its parent class, and provides a new or modified implementation for it.

# %% [markdown]
# # 13. What is a property decorator in Python
# Answer:-A property decorator property allows you to use a method like an attribute. It is used to control access to instance variables - like getters, setters, and deleters - without changing how you use them.

# %% [markdown]
# # 14.Why is polymorphism important in OOP
# Answer:-Polymorphism means the same function or method name can perform different actions depending on the object that calls it.

# %% [markdown]
# # 15.What is an abstract class in Python
# Answer:-An abstract class is a blueprint (template) for other classes. It defines methods that must be implemented in any class that inherits from it.
#
# - You cannot create an object of an abstract class directly.
# - It only tells what should be done, not how it should be done.

# %% [markdown]
# # 16.What are the advantages of OOP?
# Answer:-OOP is a programming approach where you organize your code using objects —
# each object represents a real-world entity (like a car, student, employee, etc.)
# and combines data (attributes) and behavior (methods) together.

# %% [markdown]
# # 17.What is the difference between a class variable and an instance variable?
# Answer:-Class Variable
#
# A class variable is a variable that is shared by all objects (instances) of a class. It belongs to the class itself, not to any one object.
#
# - Instance Variable
#
# An instance variable is a variable that is unique to each object.
# It is defined inside the constructor (__init__) using self.

# %% [markdown]
# # 18.What is multiple inheritance in Python
# Answer:-Multiple Inheritance in Python means that a child class can inherit properties and methods from more than one parent class. It allows a single class to combine the features of multiple classes without rewriting the same code again.

# %% [markdown]
# # 19.Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python
# Answer:-1 __str__() Method
#
# The __str__() method is used to define a user-friendly (readable) string representation of an object.
# It’s mainly meant for end users — i.e., when you print an object, it should look nice and understandable.
#
# 2. __repr__() Method
#
# The __repr__() method is used to define an unambiguous, developer-oriented string representation of the object —
# something that helps debugging or recreating the object.

# %%
# __str__() Method
class Student:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def __str__(self):
        return f"Student Name: {self.name}, Age: {self.age}"

s1 = Student("Aashish", 20)
print(s1)
# Out:
# Student Name: Aashish, Age: 20

# %%
# __repr__() Method
class Student:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def __repr__(self):
        return f"Student('{self.name}', {self.age})"

s1 = Student("Aashish", 20)
print(repr(s1))
# Out:
# Student('Aashish', 20)

# %% [markdown]
# # 20.What is the significance of the ‘super()’ function in Python
# Answer:-The super() function in Python is used to call methods of a parent (super) class from within a child class.
# It allows you to access and reuse parent class features without directly naming the parent class — making code cleaner and easier to maintain.

# %% [markdown]
# # 21.What is the significance of the __del__ method in Python
# Answer:-The __del__() method in Python is a destructor.
# It is called automatically when an object is about to be destroyed or deleted from memory.
# Its main purpose is to release resources or perform cleanup tasks before the object is removed.

# %% [markdown]
# # 22.What is the difference between @staticmethod and @classmethod in Python
# Answer:-@classmethod
#
# A class method takes cls as its first argument (instead of self).
#
# It can access or modify class variables, but not instance variables.
#
# It is called using the class name or an object.
#
# - @staticmethod
#
# A static method does not take self or cls as its first argument.
#
# It cannot access class or instance variables.
#
# It behaves like a normal function, but it’s inside the class for logical grouping.

# %% [markdown]
# # 23.How does polymorphism work in Python with inheritance
# Answer:-Polymorphism means “many forms” - it allows the same method name to behave differently depending on the object that calls it.
#
# In inheritance, polymorphism works when a child class overrides a method of its parent class, but keeps the same method name.
# When we call that method using a parent reference, the child class version gets executed — not the parent’s.

# %% [markdown]
# # 24.What is method chaining in Python OOP
# Answer:-Method Chaining is a technique in Python where multiple methods are called on the same object in a single line, one after another. It works when methods return the object itself (self) after performing their action.

# %% [markdown]
# # 25.What is the purpose of the __call__ method in Python?
# Answer:-The __call__() method in Python allows an object of a class to be called like a function.
# In other words, you can “call” an instance and it will execute the code defined in __call__().
#
# It’s useful when you want objects to behave like functions or need flexible callable objects.

# %% [markdown]
# # **PRACTICAL QUESTIONS**

# %% [markdown]
# # 1.Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog that overrides the speak() method to print "Bark!"

# %%
class Animal:
    def speak(self):
        print("Animal makes a sound")
class Dog(Animal):
    def speak(self):
        print("Bark!")
d = Dog()
d.speak()
# Out:
# Bark!

# %% [markdown]
# # 2.Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle from it and implement the area() method in both.

# %%
from abc import ABC, abstractmethod

# Abstract class
class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

# Child class 1
class Circle(Shape):
    def area(self):
        print("Area of Circle = π × r × r")

class Rectangle(Shape):
    def area(self):
        print("Area of Rectangle = length × breadth")
c = Circle()
r = Rectangle()

c.area()
r.area()
# Out:
# Area of Circle = π × r × r
# Area of Rectangle = length × breadth

# %% [markdown]
# # 3.Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car and further derive a class ElectricCar that adds a battery attribute.

# %%
class Vehicle:
    def __init__(self, vehicle_type):
        self.type = vehicle_type

    def show_type(self):
        print("Vehicle Type:", self.type)

class Car(Vehicle):
    def __init__(self, vehicle_type, brand):
        super().__init__(vehicle_type)
        self.brand = brand

    def show_brand(self):
        print("Car Brand:", self.brand)
class ElectricCar(Car):
    def __init__(self, vehicle_type, brand, battery):
        super().__init__(vehicle_type, brand)
        self.battery = battery

    def show_details(self):
        print("Vehicle Type:", self.type)
        print("Brand:", self.brand)
        print("Battery Capacity:", self.battery)
e = ElectricCar("Four Wheeler", "Tesla", "75 kWh")
e.show_details()
# Out:
# Vehicle Type: Four Wheeler
# Brand: Tesla
# Battery Capacity: 75 kWh

# %% [markdown]
# # 4.Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes Sparrow and Penguin that override the fly() method.

# %%
class Bird:
    def fly(self):
        print("Some birds can fly, some cannot.")

# Derived class 1
class Sparrow(Bird):
    def fly(self):
        print("Sparrow can fly high in the sky!")

# Derived class 2
class Penguin(Bird):
    def fly(self):
        print("Penguins cannot fly, they swim instead.")

# Polymorphism demonstration
birds = [Sparrow(), Penguin()]

for bird in birds:
    bird.fly()
# Out:
# Sparrow can fly high in the sky!
# Penguins cannot fly, they swim instead.

# %% [markdown]
# # 5.Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes balance and methods to deposit, withdraw, and check balance.

# %%
class BankAccount:
    def __init__(self):
        self.__balance = 0

    def deposit(self, amount):
        self.__balance += amount
        print("Deposit successful!")

    def withdraw(self, amount):
        if amount <= self.__balance:
            self.__balance -= amount
            print("Withdraw successful!")
        else:
            print("Not enough balance.")

    def check_balance(self):
        print("Current balance:", self.__balance)
account = BankAccount()

account.deposit(1000)
account.withdraw(300)
account.check_balance()
# Out:
# Deposit successful!
# Withdraw successful!
# Current balance: 700

# %% [markdown]
# # 6.Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar and Piano that implement their own version of play().

# %%
class Instrument:
    def play(self):
        print("Playing an instrument...")

# Derived class 1
class Guitar(Instrument):
    def play(self):
        print("Strumming the guitar 🎸")

# Derived class 2
class Piano(Instrument):
    def play(self):
        print("Playing the piano 🎹")

instruments = [Guitar(), Piano()]

for instrument in instruments:
    instrument.play()   # Same method name, different behavior at runtime
# Out:
# Strumming the guitar 🎸
# Playing the piano 🎹

# %% [markdown]
# # 7.Create a class MathOperations with a class method add_numbers() to add two numbers and a static method subtract_numbers() to subtract two numbers.

# %%
class MathOperations:
    # Class Method
    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    # Static Method
    @staticmethod
    def subtract_numbers(a, b):
        return a - b


# Using class method
sum_result = MathOperations.add_numbers(10, 5)
print("Addition:", sum_result)

# Using static method
sub_result = MathOperations.subtract_numbers(10, 5)
print("Subtraction:", sub_result)
# Out:
# Addition: 15
# Subtraction: 5

# %% [markdown]
# # 8.Implement a class Person with a class method to count the total number of persons created.

# %%
class Person:
    count = 0

    def __init__(self, name):
        self.name = name
        Person.count += 1

    # Class method
    @classmethod
    def total_persons(cls):
        print("Total persons created:", cls.count)


# Object creation
p1 = Person("Aashish")
p2 = Person("Ravi")
p3 = Person("Ankit")

Person.total_persons()
# Out:
# Total persons created: 3

# %% [markdown]
# # 9.Write a class Fraction with attributes numerator and denominator. Override the str method to display the fraction as "numerator/denominator".

# %%
class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator
    def __str__(self):
        return f"{self.numerator}/{self.denominator}"


f1 = Fraction(3, 4)
f2 = Fraction(5, 8)

print(f1)
print(f2)
# Out:
# 3/4
# 5/8

# %% [markdown]
# # 10.Demonstrate operator overloading by creating a class Vector and overriding the add method to add two vectors.

# %%
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    def __str__(self):
        return f"Vector({self.x}, {self.y})"
v1 = Vector(2, 5)
v2 = Vector(3, 7)

v3 = v1 + v2
print(v3)
# Out:
# Vector(5, 12)

# %% [markdown]
# # 11.Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is {name} and I am {age} years old."

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")
p1 = Person("Aashish", 21)

p1.greet()
# Out:
# Hello, my name is Aashish and I am 21 years old.

# %% [markdown]
# # 12.Implement a class Student with attributes name and grades. Create a method average_grade() to compute the average of the grades.

# %%
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades

    def average_grade(self):
        if len(self.grades) == 0:
            return 0
        return sum(self.grades) / len(self.grades)

s1 = Student("Aashish", [85, 90, 78, 92])
avg = s1.average_grade()
print(f"{s1.name}'s average grade is: {avg:.2f}")
# Out:
# Aashish's average grade is: 86.25

# %% [markdown]
# # 13.Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the area.

# %%
class Rectangle:
    def __init__(self):
        self.length = 0
        self.width = 0

    def set_dimensions(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width


# Object creation
rect = Rectangle()

# Setting dimensions
rect.set_dimensions(5, 3)

# Calculating area
print("Area of rectangle:", rect.area())
# Out:
# Area of rectangle: 15

# %% [markdown]
# # 14.Create a class Employee with a method calculate_salary() that computes the salary based on hours worked and hourly rate. Create a derived class Manager that adds a bonus to the salary.

# %%
# Base class
class Employee:
    def __init__(self, name, hours_worked, hourly_rate):
        self.name = name
        self.hours_worked = hours_worked
        self.hourly_rate = hourly_rate

    def calculate_salary(self):
        return self.hours_worked * self.hourly_rate


# Derived class
class Manager(Employee):
    def __init__(self, name, hours_worked, hourly_rate, bonus):
        super().__init__(name, hours_worked, hourly_rate)
        self.bonus = bonus

    def calculate_salary(self):
        base_salary = super().calculate_salary()
        return base_salary + self.bonus


emp1 = Employee("Ravi", 40, 200)
mgr1 = Manager("Aashish", 40, 300, 5000)

print(f"{emp1.name}'s Salary: ₹{emp1.calculate_salary()}")
print(f"{mgr1.name}'s Salary: ₹{mgr1.calculate_salary()}")
# Out:
# Ravi's Salary: ₹8000
# Aashish's Salary: ₹17000

# %% [markdown]
# # 15.Create a class Product with attributes name, price, and quantity. Implement a method total_price() that calculates the total price of the product.

# %%
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    # Method to calculate total price
    def total_price(self):
        return self.price * self.quantity

p1 = Product("Notebook", 50, 10)

print(f"Total price of {p1.name}: ₹{p1.total_price()}")
# Out:
# Total price of Notebook: ₹500

# %% [markdown]
# # 16.Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that implement the sound() method.

# %%
from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass


# Derived class 1
class Cow(Animal):
    def sound(self):
        return "Moo Moo "


# Derived class 2
class Sheep(Animal):
    def sound(self):
        return "Baa Baa "


# Creating objects
cow = Cow()
sheep = Sheep()

# Calling methods
print("Cow sound:", cow.sound())
print("Sheep sound:", sheep.sound())
# Out:
# Cow sound: Moo Moo
# Sheep sound: Baa Baa

# %% [markdown]
# 17. Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that returns a formatted string with the book's details

# %%
class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    # Method to return book information
    def get_book_info(self):
        return f"'{self.title}' by {self.author}, published in {self.year_published}."


# Creating object
book1 = Book("Wings of Fire", "A.P.J. Abdul Kalam", 1999)

# Displaying book information
print(book1.get_book_info())
# Out:
# 'Wings of Fire' by A.P.J. Abdul Kalam, published in 1999.

# %% [markdown]
# # 18.Create a class House with attributes address and price. Create a derived class Mansion that adds an attribute number_of_rooms.

# %%
# Base class
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price


# Derived class
class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms

    def show_details(self):
        print(f"Address: {self.address}")
        print(f"Price: ₹{self.price}")
        print(f"Number of Rooms: {self.number_of_rooms}")


# Creating object
m1 = Mansion("123 Luxury Street, Sonipat", 500000, 10)

# Displaying mansion details
m1.show_details()
# Out:
# Address: 123 Luxury Street, Sonipat
# Price: ₹500000
# Number of Rooms: 10
